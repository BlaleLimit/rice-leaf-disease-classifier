# %% [markdown]
# <h2>Recognition System for Rice Leaf Diseases<h2>

# %%
import pandas as pd
import numpy as np
import cv2
from PIL import Image
from skimage.color import rgb2gray, rgb2hsv

import seaborn as sb

import sys
import gc
import torch

import os
import pickle
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K

from sklearn.model_selection import train_test_split, StratifiedKFold

from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint,CSVLogger
from tensorflow.keras import regularizers
from tensorflow.python.client import device_lib
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv2D, Activation, Lambda, MaxPool2D, Flatten, Dropout, Dense, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator


#Visualization and Plotting
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score, f1_score, accuracy_score

# %% [markdown]
# # Set GPU for faster computations

# %%
#Ako'y ALAPIN NG GPU KOOOOOOO
print(device_lib.list_local_devices())
phy_device = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(phy_device[0],True)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13144807204919537109
# xla_global_id: -1
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 2963419956
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 1970229459799756870
# physical_device_desc: "device: 0, name: NVIDIA GeForce GTX 850M, pci bus id: 0000:01:00.0, compute capability: 5.0"
# xla_global_id: 416903419
# ]

# %% [markdown]
# # 1. Prepare all necessary components

# %% [markdown]
# ## 1.1a Loading Old Datasets with 4 classes

# %%
#Loading Pickled training and testing datasets
X_train = pickle.load(open('pickles\\X_orig_lab.pickle', 'rb'))
y_train = pickle.load(open('pickles\\y_orig_lab.pickle', 'rb'))


y_train = np.array(y_train)
X_train = X_train/255


X_testing = pickle.load(open('pickles\\X_test_orig_lab.pickle', 'rb'))
y_testing = pickle.load(open('pickles\\y_test__orig_lab.pickle', 'rb'))

y_testing = np.array(y_testing)
X_testing = X_testing/255

#Loading Pickled threshed training and testing datasets
X_train_cropped = pickle.load(open('pickles\\X_cropped_lab2_blur.pickle', 'rb'))
y_train_cropped = pickle.load(open('pickles\\y_cropped_lab2_blur.pickle', 'rb'))


y_train_cropped = np.array(y_train_cropped)
X_train_cropped = X_train_cropped/255


X_testing_cropped = pickle.load(open('pickles\\X_test_cropped_lab2_blur.pickle', 'rb'))
y_testing_cropped = pickle.load(open('pickles\\y_test_cropped_lab2_blur.pickle', 'rb'))

y_testing_cropped = np.array(y_testing_cropped)
X_testing_cropped = X_testing_cropped/255

X_train_g1 = pickle.load(open('pickles\\X_g1.pickle', 'rb'))
y_train_g1 = pickle.load(open('pickles\\y_g1.pickle', 'rb'))


y_train_g1 = np.array(y_train_g1)
X_train_g1 = X_train_g1/255


X_testing_g1 = pickle.load(open('pickles\\X_test_g1.pickle', 'rb'))
y_testing_g1 = pickle.load(open('pickles\\y_test_g1.pickle', 'rb'))

y_testing_g1 = np.array(y_testing_g1)
X_testing_g1 = X_testing_g1/255



classes = ["BrownSpot", "Healthy", "Hispa", "LeafBlast"]

print(X_train_cropped.shape)
print(y_train_cropped.shape)

print(X_testing_cropped.shape)
print(y_testing_cropped.shape)

print(X_train_g1.shape)

print(X_testing_g1.shape)

y_train[:5]

# %% [markdown]
# ## 1.1b Loading Dataset with 3 classes (Blight, Brown spots, Leaf smut)

# %%
classes = ["Bacterial leaf blight", "Brown spot", "Leaf smut"]

# %%
#Loading Pickled training and testing datasets
X_train = pickle.load(open('pickles\\small_dataset\\X_train_3_classes.pickle', 'rb'))
y_train = pickle.load(open('pickles\\small_dataset\\y_train_3_classes.pickle', 'rb'))

X_train = X_train/255
y_train = np.array(y_train)


X_val = pickle.load(open('pickles\\small_dataset\\X_val_3_classes.pickle', 'rb'))
y_val = pickle.load(open('pickles\\small_dataset\\y_val_3_classes.pickle', 'rb'))

X_val = X_val/255
y_val = np.array(y_val)

X_test = pickle.load(open('pickles\\small_dataset\\X_test_3_classes.pickle', 'rb'))
y_test = pickle.load(open('pickles\\small_dataset\\y_test_3_classes.pickle', 'rb'))

X_test = X_test/255
y_test = np.array(y_test)

print(X_train.shape)
print(X_test.shape)
print(X_val.shape)

# %% [markdown]
# ## 1.1c Dataset for K-fold Cross Validation

# %%
X_dataset = pickle.load(open('pickles\\small_dataset\\X_dataset_3_classes.pickle', 'rb'))
y_dataset = pickle.load(open('pickles\\small_dataset\\y_dataset_3_classes.pickle', 'rb'))

y_dataset = np.array(y_dataset)
# print(y_dataset[0])
# print(type(y_dataset))
# # print(y_dataset[0])
# print(type(X_dataset))
# # print(X_dataset[0])

#Splitting dataset into training and testing
X_train, X_test, y_train, y_test = train_test_split(X_dataset, y_dataset, test_size = 0.10, shuffle = True, 
                                                    random_state = 42)
print(y_train[:5])
print(y_test[:5])
# Out:
# [2 1 0 0 0]
# [1 1 1 2 1]

# %% [markdown]
# ## 1.2 Visualization from pickle files

# %%
#Visualize images in training dataset
fig, axes = plt.subplots(2, 5, figsize = (15,10))
#TRUE LABEL of Training Data
for index in range(10):   
    ax = axes[index//5, index%5]
    ax.imshow(X_train[index])
    ax.set_title(classes[y_train[index]]) 
plt.tight_layout()
plt.show()

# %%
#Visualize images in testing dataset
fig, axes = plt.subplots(4, 5, figsize = (15,10))
#TRUE LABEL of Testing Data
for index in range(20):   
    ax = axes[index//5, index%5]
    ax.imshow(X_test[index])
    ax.set_title(classes[y_test[index]]) 
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Define Visual Attention, Early Stopping, Checkpoints, and CSVLogger

# %%
#From https://github.com/EscVM/EscVM_YT/blob/master/Notebooks/0%20-%20TF2.X%20Tutorials/tf_2_visual_attention.ipynb
#By EscVM
class ChannelAttention(tf.keras.layers.Layer):
      def __init__(self, filters, ratio):
        super(ChannelAttention, self).__init__()
        self.filters = filters
        self.ratio = ratio

        def build(self, input_shape):
            self.shared_layer_one = tf.keras.layers.Dense(self.filters//self.ratio,
                             activation='relu', kernel_initializer='he_normal', 
                              use_bias=True, 
                              bias_initializer='zeros')
            self.shared_layer_two = tf.keras.layers.Dense(self.filters,
                             kernel_initializer='he_normal',
                             use_bias=True,
                             bias_initializer='zeros')

        def call(self, inputs):
            # AvgPool
            avg_pool = tf.keras.layers.GlobalAveragePooling2D()(inputs)
            avg_pool = self.shared_layer_one(avg_pool)
            avg_pool = self.shared_layer_two(avg_pool)
            # MaxPool
            max_pool = tf.keras.layers.GlobalMaxPooling2D()(inputs)
            max_pool = tf.keras.layers.Reshape((1,1,filters))(max_pool)
            max_pool = self.shared_layer_one(max_pool)
            max_pool = self.shared_layer_two(max_pool)

            attention = tf.keras.layers.Add()([avg_pool,max_pool])
            attention = tf.keras.layers.Activation('sigmoid')(attention)
            
            return tf.keras.layers.Multiply()([inputs, attention])
    
class SpatialAttention(tf.keras.layers.Layer):
      def __init__(self, kernel_size):
        super(SpatialAttention, self).__init__()
        self.kernel_size = kernel_size
        
        def build(self, input_shape):
            self.conv2d = tf.keras.layers.Conv2D(filters = 1,
                    kernel_size=self.kernel_size,
                    strides=1,
                    padding='same',
                    activation='sigmoid',
                    kernel_initializer='he_normal',
                    use_bias=False)

        def call(self, inputs):
            # AvgPool
            avg_pool = tf.keras.layers.Lambda(lambda x: tf.keras.backend.mean(x, axis=3, keepdims=True))(inputs)
            # MaxPool
            max_pool = tf.keras.layers.Lambda(lambda x: tf.keras.backend.max(x, axis=3, keepdims=True))(inputs)

            attention = tf.keras.layers.Concatenate(axis=3)([avg_pool, max_pool])
            attention = self.conv2d(attention)
            
            return tf.keras.layers.multiply([inputs, attention])

# %%
# set early stopping criteria
pat = 5 # this is the number of epochs with no improvment after which the training will stop
early_stopping = EarlyStopping(monitor='val_loss', patience=pat, verbose=1, baseline=None)

# define the model checkpoint callback -> this will keep on saving the model as a physical file
model_checkpoint = ModelCheckpoint(f'model_checkpoints/acnn_model.h5', verbose=1, save_best_only=True)

# to save the history of models
csv_logger = CSVLogger(f'logs/acnn_model.log', separator=",", append=True)

#Kernel_regulizer to minimize overfitting/underfitting of model
regularizer = regularizers.l2(0.00020)

# %% [markdown]
# # 3. CNN Models

# %% [markdown]
# ## 3.1 CNN Model with no Visual Attention

# %% [markdown]
# #### 3.1.1 Training CNN Model

# %%
#AlexNet CNN Model with no visual attention
def build_model_no_attention():
    
    acnn_model = Sequential()
    optimizer = tf.keras.optimizers.Adam(0.0000088)
    
    acnn_model.add(Conv2D(filters = 96, kernel_size = (11,11), strides = (4,4), padding = 'same', activation = 'relu',
                      input_shape = (224,224,3), data_format = 'channels_last'))
    # acnn_model.add(Lambda(tf.nn.local_response_normalization))
    acnn_model.add(BatchNormalization())
    acnn_model.add(MaxPool2D(pool_size =(3,3), strides = (2,2)))


    acnn_model.add(Conv2D(filters = 256, kernel_size = (5,5), strides=(1,1), padding='same', activation = 'relu'))
    # acnn_model.add(Lambda(tf.nn.local_response_normalization))
    acnn_model.add(BatchNormalization())
    acnn_model.add(MaxPool2D(pool_size =(3,3), strides = (2,2)))

    acnn_model.add(Conv2D(filters = 384, kernel_size = (3,3), strides=(1,1), padding='same', activation = 'relu'))
    # acnn_model.add(Lambda(tf.nn.local_response_normalization))
    acnn_model.add(BatchNormalization())
    acnn_model.add(Conv2D(filters = 384, kernel_size = (3,3), strides=(1,1), padding='same', activation = 'relu'))
    # acnn_model.add(Lambda(tf.nn.local_response_normalization))
    acnn_model.add(BatchNormalization())
    acnn_model.add(Conv2D(filters = 256, kernel_size = (3,3), strides=(1,1), padding='same', activation = 'relu'))
    # acnn_model.add(Lambda(tf.nn.local_response_normalization))
    acnn_model.add(BatchNormalization())
    acnn_model.add(MaxPool2D(pool_size = (3,3), strides = (2,2) ))

    acnn_model.add(Flatten())
    acnn_model.add(Dense(100, activation ='relu', kernel_regularizer= regularizer))
    acnn_model.add(Dropout(0.5))

    acnn_model.add(Dense(100, activation ='relu',kernel_regularizer= regularizer))
    acnn_model.add(Dropout(0.5))

    acnn_model.add(Dense(3, activation = 'softmax'))

    
    acnn_model.compile(loss = 'sparse_categorical_crossentropy', optimizer = optimizer, metrics= ['accuracy'])

    return acnn_model

# %%
#Define AlexNet model and Train
acnn_model = build_model_no_attention()
acnn_hist = acnn_model.fit(X_train, y_train, verbose = 1, batch_size = 32,validation_split = 0.1111111111,
                   epochs=50, callbacks = [early_stopping, model_checkpoint, csv_logger])
# Out:
# Epoch 1/50
# 63/63 [==============================] - ETA: 0s - loss: 2.3683 - accuracy: 0.3378
# Epoch 1: val_loss improved from inf to 1.18773, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 30s 347ms/step - loss: 2.3683 - accuracy: 0.3378 - val_loss: 1.1877 - val_accuracy: 0.3571
# Epoch 2/50
# 63/63 [==============================] - ETA: 0s - loss: 1.4216 - accuracy: 0.4053
# Epoch 2: val_loss improved from 1.18773 to 1.14087, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 253ms/step - loss: 1.4216 - accuracy: 0.4053 - val_loss: 1.1409 - val_accuracy: 0.3651
# Epoch 3/50
# 63/63 [==============================] - ETA: 0s - loss: 1.2224 - accuracy: 0.4216
# Epoch 3: val_loss improved from 1.14087 to 1.10981, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 260ms/step - loss: 1.2224 - accuracy: 0.4216 - val_loss: 1.1098 - val_accuracy: 0.4246
# Epoch 4/50
# 63/63 [==============================] - ETA: 0s - loss: 1.1390 - accuracy: 0.4430
# Epoch 4: val_loss improved from 1.10981 to 1.07735, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 17s 272ms/step - loss: 1.1390 - accuracy: 0.4430 - val_loss: 1.0773 - val_accuracy: 0.4603
# Epoch 5/50
# 63/63 [==============================] - ETA: 0s - loss: 1.0884 - accuracy: 0.4782
# Epoch 5: val_loss improved from 1.07735 to 1.06292, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 17s 266ms/step - loss: 1.0884 - accuracy: 0.4782 - val_loss: 1.0629 - val_accuracy: 0.5040
# Epoch 6/50
# 63/63 [==============================] - ETA: 0s - loss: 1.0655 - accuracy: 0.4841
# Epoch 6: val_loss improved from 1.06292 to 1.03088, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 255ms/step - loss: 1.0655 - accuracy: 0.4841 - val_loss: 1.0309 - val_accuracy: 0.5317
# Epoch 7/50
# 63/63 [==============================] - ETA: 0s - loss: 1.0258 - accuracy: 0.5079
# Epoch 7: val_loss improved from 1.03088 to 1.00923, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 256ms/step - loss: 1.0258 - accuracy: 0.5079 - val_loss: 1.0092 - val_accuracy: 0.5556
# Epoch 8/50
# 63/63 [==============================] - ETA: 0s - loss: 0.9801 - accuracy: 0.5491
# Epoch 8: val_loss improved from 1.00923 to 0.96275, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 251ms/step - loss: 0.9801 - accuracy: 0.5491 - val_loss: 0.9628 - val_accuracy: 0.5913
# Epoch 9/50
# 63/63 [==============================] - ETA: 0s - loss: 0.9759 - accuracy: 0.5501
# Epoch 9: val_loss improved from 0.96275 to 0.95221, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 251ms/step - loss: 0.9759 - accuracy: 0.5501 - val_loss: 0.9522 - val_accuracy: 0.6071
# Epoch 10/50
# 63/63 [==============================] - ETA: 0s - loss: 0.9396 - accuracy: 0.5694
# Epoch 10: val_loss improved from 0.95221 to 0.91906, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 251ms/step - loss: 0.9396 - accuracy: 0.5694 - val_loss: 0.9191 - val_accuracy: 0.6270
# Epoch 11/50
# 63/63 [==============================] - ETA: 0s - loss: 0.9309 - accuracy: 0.5655
# Epoch 11: val_loss improved from 0.91906 to 0.89112, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 251ms/step - loss: 0.9309 - accuracy: 0.5655 - val_loss: 0.8911 - val_accuracy: 0.6190
# Epoch 12/50
# 63/63 [==============================] - ETA: 0s - loss: 0.8981 - accuracy: 0.5868
# Epoch 12: val_loss did not improve from 0.89112
# 63/63 [==============================] - 16s 246ms/step - loss: 0.8981 - accuracy: 0.5868 - val_loss: 0.8928 - val_accuracy: 0.6349
# Epoch 13/50
# 63/63 [==============================] - ETA: 0s - loss: 0.8691 - accuracy: 0.6096
# Epoch 13: val_loss improved from 0.89112 to 0.86800, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 251ms/step - loss: 0.8691 - accuracy: 0.6096 - val_loss: 0.8680 - val_accuracy: 0.6667
# Epoch 14/50
# 63/63 [==============================] - ETA: 0s - loss: 0.8366 - accuracy: 0.6359
# Epoch 14: val_loss improved from 0.86800 to 0.84035, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 251ms/step - loss: 0.8366 - accuracy: 0.6359 - val_loss: 0.8403 - val_accuracy: 0.6746
# Epoch 15/50
# 63/63 [==============================] - ETA: 0s - loss: 0.7933 - accuracy: 0.6503
# Epoch 15: val_loss did not improve from 0.84035
# 63/63 [==============================] - 16s 248ms/step - loss: 0.7933 - accuracy: 0.6503 - val_loss: 0.8435 - val_accuracy: 0.6627
# Epoch 16/50
# 63/63 [==============================] - ETA: 0s - loss: 0.7907 - accuracy: 0.6597
# Epoch 16: val_loss improved from 0.84035 to 0.79706, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 252ms/step - loss: 0.7907 - accuracy: 0.6597 - val_loss: 0.7971 - val_accuracy: 0.6825
# Epoch 17/50
# 63/63 [==============================] - ETA: 0s - loss: 0.7602 - accuracy: 0.6766
# Epoch 17: val_loss did not improve from 0.79706
# 63/63 [==============================] - 16s 247ms/step - loss: 0.7602 - accuracy: 0.6766 - val_loss: 0.8056 - val_accuracy: 0.6786
# Epoch 18/50
# 63/63 [==============================] - ETA: 0s - loss: 0.7221 - accuracy: 0.7044
# Epoch 18: val_loss improved from 0.79706 to 0.77358, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 253ms/step - loss: 0.7221 - accuracy: 0.7044 - val_loss: 0.7736 - val_accuracy: 0.7262
# Epoch 19/50
# 63/63 [==============================] - ETA: 0s - loss: 0.7260 - accuracy: 0.7118
# Epoch 19: val_loss improved from 0.77358 to 0.73775, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 252ms/step - loss: 0.7260 - accuracy: 0.7118 - val_loss: 0.7378 - val_accuracy: 0.7183
# Epoch 20/50
# 63/63 [==============================] - ETA: 0s - loss: 0.7028 - accuracy: 0.7183
# Epoch 20: val_loss improved from 0.73775 to 0.72809, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 251ms/step - loss: 0.7028 - accuracy: 0.7183 - val_loss: 0.7281 - val_accuracy: 0.7183
# Epoch 21/50
# 63/63 [==============================] - ETA: 0s - loss: 0.6628 - accuracy: 0.7331
# Epoch 21: val_loss improved from 0.72809 to 0.72068, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 253ms/step - loss: 0.6628 - accuracy: 0.7331 - val_loss: 0.7207 - val_accuracy: 0.7103
# Epoch 22/50
# 63/63 [==============================] - ETA: 0s - loss: 0.6478 - accuracy: 0.7470
# Epoch 22: val_loss improved from 0.72068 to 0.69061, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 254ms/step - loss: 0.6478 - accuracy: 0.7470 - val_loss: 0.6906 - val_accuracy: 0.7659
# Epoch 23/50
# 63/63 [==============================] - ETA: 0s - loss: 0.6279 - accuracy: 0.7500
# Epoch 23: val_loss improved from 0.69061 to 0.66807, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 253ms/step - loss: 0.6279 - accuracy: 0.7500 - val_loss: 0.6681 - val_accuracy: 0.7421
# Epoch 24/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5878 - accuracy: 0.7773
# Epoch 24: val_loss improved from 0.66807 to 0.63871, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 252ms/step - loss: 0.5878 - accuracy: 0.7773 - val_loss: 0.6387 - val_accuracy: 0.7817
# Epoch 25/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5995 - accuracy: 0.7579
# Epoch 25: val_loss improved from 0.63871 to 0.63679, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 253ms/step - loss: 0.5995 - accuracy: 0.7579 - val_loss: 0.6368 - val_accuracy: 0.7659
# Epoch 26/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5351 - accuracy: 0.7986
# Epoch 26: val_loss improved from 0.63679 to 0.62901, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 252ms/step - loss: 0.5351 - accuracy: 0.7986 - val_loss: 0.6290 - val_accuracy: 0.7937
# Epoch 27/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5559 - accuracy: 0.7783
# Epoch 27: val_loss improved from 0.62901 to 0.62695, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 252ms/step - loss: 0.5559 - accuracy: 0.7783 - val_loss: 0.6269 - val_accuracy: 0.7937
# Epoch 28/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5159 - accuracy: 0.8075
# Epoch 28: val_loss improved from 0.62695 to 0.61468, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 252ms/step - loss: 0.5159 - accuracy: 0.8075 - val_loss: 0.6147 - val_accuracy: 0.7778
# Epoch 29/50
# 63/63 [==============================] - ETA: 0s - loss: 0.5143 - accuracy: 0.8080
# Epoch 29: val_loss improved from 0.61468 to 0.59074, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 252ms/step - loss: 0.5143 - accuracy: 0.8080 - val_loss: 0.5907 - val_accuracy: 0.7976
# Epoch 30/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4837 - accuracy: 0.8219
# Epoch 30: val_loss did not improve from 0.59074
# 63/63 [==============================] - 16s 247ms/step - loss: 0.4837 - accuracy: 0.8219 - val_loss: 0.6984 - val_accuracy: 0.7302
# Epoch 31/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4747 - accuracy: 0.8249
# Epoch 31: val_loss improved from 0.59074 to 0.58863, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 255ms/step - loss: 0.4747 - accuracy: 0.8249 - val_loss: 0.5886 - val_accuracy: 0.7897
# Epoch 32/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4607 - accuracy: 0.8418
# Epoch 32: val_loss improved from 0.58863 to 0.57253, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 252ms/step - loss: 0.4607 - accuracy: 0.8418 - val_loss: 0.5725 - val_accuracy: 0.8056
# Epoch 33/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4386 - accuracy: 0.8457
# Epoch 33: val_loss improved from 0.57253 to 0.54261, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 254ms/step - loss: 0.4386 - accuracy: 0.8457 - val_loss: 0.5426 - val_accuracy: 0.8056
# Epoch 34/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4292 - accuracy: 0.8557
# Epoch 34: val_loss did not improve from 0.54261
# 63/63 [==============================] - 16s 251ms/step - loss: 0.4292 - accuracy: 0.8557 - val_loss: 0.5476 - val_accuracy: 0.8135
# Epoch 35/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4039 - accuracy: 0.8601
# Epoch 35: val_loss improved from 0.54261 to 0.54082, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 254ms/step - loss: 0.4039 - accuracy: 0.8601 - val_loss: 0.5408 - val_accuracy: 0.8016
# Epoch 36/50
# 63/63 [==============================] - ETA: 0s - loss: 0.4017 - accuracy: 0.8651
# Epoch 36: val_loss did not improve from 0.54082
# 63/63 [==============================] - 16s 247ms/step - loss: 0.4017 - accuracy: 0.8651 - val_loss: 0.5414 - val_accuracy: 0.8095
# Epoch 37/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3720 - accuracy: 0.8785
# Epoch 37: val_loss improved from 0.54082 to 0.53875, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 256ms/step - loss: 0.3720 - accuracy: 0.8785 - val_loss: 0.5388 - val_accuracy: 0.8333
# Epoch 38/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3781 - accuracy: 0.8686
# Epoch 38: val_loss improved from 0.53875 to 0.51952, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 255ms/step - loss: 0.3781 - accuracy: 0.8686 - val_loss: 0.5195 - val_accuracy: 0.8214
# Epoch 39/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3516 - accuracy: 0.8879
# Epoch 39: val_loss did not improve from 0.51952
# 63/63 [==============================] - 16s 252ms/step - loss: 0.3516 - accuracy: 0.8879 - val_loss: 0.5727 - val_accuracy: 0.7937
# Epoch 40/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3636 - accuracy: 0.8805
# Epoch 40: val_loss did not improve from 0.51952
# 63/63 [==============================] - 16s 249ms/step - loss: 0.3636 - accuracy: 0.8805 - val_loss: 0.5517 - val_accuracy: 0.8294
# Epoch 41/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3637 - accuracy: 0.8785
# Epoch 41: val_loss improved from 0.51952 to 0.51843, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 253ms/step - loss: 0.3637 - accuracy: 0.8785 - val_loss: 0.5184 - val_accuracy: 0.8333
# Epoch 42/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.8978
# Epoch 42: val_loss improved from 0.51843 to 0.51316, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 252ms/step - loss: 0.3217 - accuracy: 0.8978 - val_loss: 0.5132 - val_accuracy: 0.8413
# Epoch 43/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3316 - accuracy: 0.8958
# Epoch 43: val_loss improved from 0.51316 to 0.48475, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 255ms/step - loss: 0.3316 - accuracy: 0.8958 - val_loss: 0.4847 - val_accuracy: 0.8532
# Epoch 44/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3075 - accuracy: 0.9067
# Epoch 44: val_loss did not improve from 0.48475
# 63/63 [==============================] - 16s 248ms/step - loss: 0.3075 - accuracy: 0.9067 - val_loss: 0.4941 - val_accuracy: 0.8492
# Epoch 45/50
# 63/63 [==============================] - ETA: 0s - loss: 0.2978 - accuracy: 0.9082
# Epoch 45: val_loss did not improve from 0.48475
# 63/63 [==============================] - 16s 251ms/step - loss: 0.2978 - accuracy: 0.9082 - val_loss: 0.5093 - val_accuracy: 0.8333
# Epoch 46/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3031 - accuracy: 0.9033
# Epoch 46: val_loss did not improve from 0.48475
# 63/63 [==============================] - 16s 250ms/step - loss: 0.3031 - accuracy: 0.9033 - val_loss: 0.4918 - val_accuracy: 0.8452
# Epoch 47/50
# 63/63 [==============================] - ETA: 0s - loss: 0.3018 - accuracy: 0.9087
# Epoch 47: val_loss did not improve from 0.48475
# 63/63 [==============================] - 16s 247ms/step - loss: 0.3018 - accuracy: 0.9087 - val_loss: 0.4917 - val_accuracy: 0.8254
# Epoch 48/50
# 63/63 [==============================] - ETA: 0s - loss: 0.2778 - accuracy: 0.9152
# Epoch 48: val_loss improved from 0.48475 to 0.48457, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 251ms/step - loss: 0.2778 - accuracy: 0.9152 - val_loss: 0.4846 - val_accuracy: 0.8413
# Epoch 49/50
# 63/63 [==============================] - ETA: 0s - loss: 0.2717 - accuracy: 0.9251
# Epoch 49: val_loss did not improve from 0.48457
# 63/63 [==============================] - 16s 248ms/step - loss: 0.2717 - accuracy: 0.9251 - val_loss: 0.5146 - val_accuracy: 0.8254
# Epoch 50/50
# 63/63 [==============================] - ETA: 0s - loss: 0.2643 - accuracy: 0.9256
# Epoch 50: val_loss improved from 0.48457 to 0.47619, saving model to model_checkpoints\acnn_model.h5
# 63/63 [==============================] - 16s 254ms/step - loss: 0.2643 - accuracy: 0.9256 - val_loss: 0.4762 - val_accuracy: 0.8651

# %% [markdown]
# #### 3.1.2 Visualization of Train-Validation Accuracy and Loss

# %%
#Visualization of Train-Validation Accuracy and Loss
accuracy = acnn_hist.history['accuracy']
val_accuracy = acnn_hist.history['val_accuracy']
loss = acnn_hist.history['loss']
val_loss = acnn_hist.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# #### 3.1.3 Model Evaluation on Testing Dataset and Summary of Model's structure

# %%
#Loading the h5 file that contains the trained model:
acnn_model = load_model("model_checkpoints\\acnn_model_no_attention_model.h5")

# %%
#Accuracy of the model based on the testing:
acnn_model.evaluate(X_test,y_test)
# Out:
# 8/8 [==============================] - 1s 79ms/step - loss: 0.2970 - accuracy: 0.9325
# [0.2970012128353119, 0.932539701461792]

# %%
acnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 56, 56, 96)        34944
#
#  batch_normalization (BatchN  (None, 56, 56, 96)       384
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 27, 27, 256)      1024
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  batch_normalization_3 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       884992
#
#  batch_normalization_4 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 100)               921700
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 4,684,807
# Trainable params: 4,682,055
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
#Get the label predictions of acnn_model
y_pred = acnn_model.predict(X_test)
na_pred_classes = [np.argmax(element) for element in y_pred]
# Out:
# 8/8 [==============================] - 1s 92ms/step

# %%
#Show the confusion matrix
classes_shortened = ["BLF", "Brown spot", "Leaf smut"]
conf_matrix = confusion_matrix(y_test, y_pred_classes)
ax = sb.heatmap(conf_matrix, annot=True, cmap='Blues')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ')
ax.xaxis.set_ticklabels(classes_shortened)
ax.yaxis.set_ticklabels(classes_shortened)
# Out:
# [Text(0, 0.5, 'BLF'), Text(0, 1.5, 'Brown spot'), Text(0, 2.5, 'Leaf smut')]

# %%
print("Classification Report: \n", classification_report(y_test, y_pred_classes, target_names=["Bacterial leaf blight", "Brown spot", "Leaf smut"]))
# Out:
# Classification Report:
#                         precision    recall  f1-score   support
#
# Bacterial leaf blight       0.93      0.94      0.94        87
#            Brown spot       0.90      0.94      0.92        81
#             Leaf smut       0.96      0.92      0.94        84
#
#              accuracy                           0.93       252
#             macro avg       0.93      0.93      0.93       252
#          weighted avg       0.93      0.93      0.93       252

# %%
#Display the error rate:
accuracy = accuracy_score(y_test, y_pred_classes)
print('Error: %.3f' % ((1-accuracy) * 100) + '%')
# Out:
# Error: 6.746%

# %% [markdown]
# ## 3.2 CNN Model with Attention

# %% [markdown]
# #### 3.2.1 Training CNN Model

# %%
#AlexNet CNN Model with visual attention
def build_model_with_attention():
    acnn_model_wa = Sequential()
    
    optimizer = tf.keras.optimizers.Adam(0.0000088)
    
    acnn_model_wa.add(Conv2D(filters = 96, kernel_size = (11,11), strides = (4,4), padding = 'same', activation = 'relu',
                      input_shape = (224,224,3), data_format = 'channels_last'))

    # acnn_model_wa.add(Lambda(tf.nn.local_response_normalization))
    acnn_model_wa.add(BatchNormalization())

    #Implement Visual Attention
    acnn_model_wa.add(ChannelAttention(96,5))
    acnn_model_wa.add(SpatialAttention(3))

    acnn_model_wa.add(MaxPool2D(pool_size =(3,3), strides = (2,2)))


    acnn_model_wa.add(Conv2D(filters = 256, kernel_size = (5,5), strides=(1,1), padding='same', activation = 'relu'))

    # acnn_model_wa.add(Lambda(tf.nn.local_response_normalization))
    acnn_model_wa.add(BatchNormalization())

    #Implement Visual Attention
    acnn_model_wa.add(ChannelAttention(256,5))
    acnn_model_wa.add(SpatialAttention(3))

    acnn_model_wa.add(MaxPool2D(pool_size =(3,3), strides = (2,2)))

    acnn_model_wa.add(Conv2D(filters = 384, kernel_size = (3,3), strides=(1,1), padding='same', activation = 'relu'))


    # acnn_model_wa.add(Lambda(tf.nn.local_response_normalization))
    acnn_model_wa.add(BatchNormalization())

    #Implement Visual Attention
    acnn_model_wa.add(ChannelAttention(384,5))
    acnn_model_wa.add(SpatialAttention(3))

    acnn_model_wa.add(Conv2D(filters = 384, kernel_size = (3,3), strides=(1,1), padding='same', activation = 'relu'))


    # acnn_model_wa.add(Lambda(tf.nn.local_response_normalization))
    acnn_model_wa.add(BatchNormalization())

    #Implement Visual Attention
    acnn_model_wa.add(ChannelAttention(384,5))
    acnn_model_wa.add(SpatialAttention(3))

    acnn_model_wa.add(Conv2D(filters = 256, kernel_size = (3,3), strides=(1,1), padding='same', activation = 'relu'))


    # acnn_model_wa.add(Lambda(tf.nn.local_response_normalization))
    acnn_model_wa.add(BatchNormalization())

    #Implement Visual Attention
    acnn_model_wa.add(ChannelAttention(256,5))
    acnn_model_wa.add(SpatialAttention(3))

    acnn_model_wa.add(MaxPool2D(pool_size = (3,3), strides = (2,2) ))

    acnn_model_wa.add(Flatten())
    acnn_model_wa.add(Dense(100, activation ='relu', kernel_regularizer= regularizer))
    acnn_model_wa.add(Dropout(0.5))

    acnn_model_wa.add(Dense(100, activation ='relu', kernel_regularizer= regularizer))
    acnn_model_wa.add(Dropout(0.5))

    acnn_model_wa.add(Dense(3, activation = 'softmax'))

    
    acnn_model_wa.compile(loss = 'sparse_categorical_crossentropy', optimizer = optimizer, metrics= ['accuracy'])

    return acnn_model_wa

# %%
acnn_model_wa = build_model_with_attention()
acnn_wa_hist = acnn_model_wa.fit(X_train, y_train, verbose = 1, batch_size = 32,validation_split = 0.1111111111,
                   epochs=50, callbacks = [early_stopping, csv_logger])
# Out:
# Epoch 1/50
# 63/63 [==============================] - 27s 327ms/step - loss: 2.3044 - accuracy: 0.3313 - val_loss: 1.2178 - val_accuracy: 0.3333
# Epoch 2/50
# 63/63 [==============================] - 15s 236ms/step - loss: 1.3598 - accuracy: 0.3755 - val_loss: 1.1433 - val_accuracy: 0.3929
# Epoch 3/50
# 63/63 [==============================] - 15s 235ms/step - loss: 1.2052 - accuracy: 0.4082 - val_loss: 1.1161 - val_accuracy: 0.4484
# Epoch 4/50
# 63/63 [==============================] - 14s 225ms/step - loss: 1.1482 - accuracy: 0.4251 - val_loss: 1.0898 - val_accuracy: 0.5000
# Epoch 5/50
# 63/63 [==============================] - 14s 223ms/step - loss: 1.0911 - accuracy: 0.4544 - val_loss: 1.0701 - val_accuracy: 0.4960
# Epoch 6/50
# 63/63 [==============================] - 14s 224ms/step - loss: 1.0689 - accuracy: 0.4628 - val_loss: 1.0456 - val_accuracy: 0.5079
# Epoch 7/50
# 63/63 [==============================] - 14s 226ms/step - loss: 1.0305 - accuracy: 0.5064 - val_loss: 1.0296 - val_accuracy: 0.5159
# Epoch 8/50
# 63/63 [==============================] - 14s 226ms/step - loss: 1.0098 - accuracy: 0.4950 - val_loss: 1.0150 - val_accuracy: 0.5000
# Epoch 9/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.9990 - accuracy: 0.5084 - val_loss: 0.9874 - val_accuracy: 0.5119
# Epoch 10/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.9626 - accuracy: 0.5357 - val_loss: 0.9428 - val_accuracy: 0.5794
# Epoch 11/50
# 63/63 [==============================] - 14s 223ms/step - loss: 0.9458 - accuracy: 0.5516 - val_loss: 0.9279 - val_accuracy: 0.5833
# Epoch 12/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.9329 - accuracy: 0.5630 - val_loss: 0.9178 - val_accuracy: 0.6151
# Epoch 13/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.9066 - accuracy: 0.5685 - val_loss: 0.9136 - val_accuracy: 0.6190
# Epoch 14/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.8831 - accuracy: 0.5868 - val_loss: 0.8667 - val_accuracy: 0.6825
# Epoch 15/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.8537 - accuracy: 0.6042 - val_loss: 0.8435 - val_accuracy: 0.6706
# Epoch 16/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.8346 - accuracy: 0.6295 - val_loss: 0.8370 - val_accuracy: 0.6786
# Epoch 17/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.7879 - accuracy: 0.6399 - val_loss: 0.7945 - val_accuracy: 0.6944
# Epoch 18/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.7763 - accuracy: 0.6632 - val_loss: 0.8046 - val_accuracy: 0.6984
# Epoch 19/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.7520 - accuracy: 0.6662 - val_loss: 0.7951 - val_accuracy: 0.7063
# Epoch 20/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.7614 - accuracy: 0.6711 - val_loss: 0.7595 - val_accuracy: 0.7222
# Epoch 21/50
# 63/63 [==============================] - 14s 227ms/step - loss: 0.7253 - accuracy: 0.6860 - val_loss: 0.7459 - val_accuracy: 0.7262
# Epoch 22/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.6943 - accuracy: 0.7148 - val_loss: 0.7080 - val_accuracy: 0.7540
# Epoch 23/50
# 63/63 [==============================] - 14s 228ms/step - loss: 0.6940 - accuracy: 0.7178 - val_loss: 0.6820 - val_accuracy: 0.7619
# Epoch 24/50
# 63/63 [==============================] - 15s 231ms/step - loss: 0.6592 - accuracy: 0.7336 - val_loss: 0.6896 - val_accuracy: 0.7579
# Epoch 25/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.6293 - accuracy: 0.7440 - val_loss: 0.6631 - val_accuracy: 0.7659
# Epoch 26/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.6200 - accuracy: 0.7525 - val_loss: 0.6663 - val_accuracy: 0.7659
# Epoch 27/50
# 63/63 [==============================] - 14s 227ms/step - loss: 0.5976 - accuracy: 0.7674 - val_loss: 0.6308 - val_accuracy: 0.7857
# Epoch 28/50
# 63/63 [==============================] - 15s 234ms/step - loss: 0.5862 - accuracy: 0.7634 - val_loss: 0.6181 - val_accuracy: 0.7976
# Epoch 29/50
# 63/63 [==============================] - 14s 227ms/step - loss: 0.5538 - accuracy: 0.7837 - val_loss: 0.5994 - val_accuracy: 0.8056
# Epoch 30/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.5372 - accuracy: 0.7966 - val_loss: 0.6145 - val_accuracy: 0.8095
# Epoch 31/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.5045 - accuracy: 0.8090 - val_loss: 0.6003 - val_accuracy: 0.7778
# Epoch 32/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.4991 - accuracy: 0.8165 - val_loss: 0.5505 - val_accuracy: 0.8095
# Epoch 33/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.4842 - accuracy: 0.8284 - val_loss: 0.5471 - val_accuracy: 0.8175
# Epoch 34/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.4435 - accuracy: 0.8413 - val_loss: 0.5668 - val_accuracy: 0.8056
# Epoch 35/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.4407 - accuracy: 0.8452 - val_loss: 0.5430 - val_accuracy: 0.8214
# Epoch 36/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.4377 - accuracy: 0.8482 - val_loss: 0.5158 - val_accuracy: 0.8294
# Epoch 37/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.4244 - accuracy: 0.8497 - val_loss: 0.4907 - val_accuracy: 0.8452
# Epoch 38/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.4271 - accuracy: 0.8512 - val_loss: 0.5035 - val_accuracy: 0.8214
# Epoch 39/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.3878 - accuracy: 0.8651 - val_loss: 0.4982 - val_accuracy: 0.8452
# Epoch 40/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.3879 - accuracy: 0.8571 - val_loss: 0.4847 - val_accuracy: 0.8571
# Epoch 41/50
# 63/63 [==============================] - 14s 226ms/step - loss: 0.3608 - accuracy: 0.8810 - val_loss: 0.4926 - val_accuracy: 0.8532
# Epoch 42/50
# 63/63 [==============================] - 14s 229ms/step - loss: 0.3414 - accuracy: 0.8884 - val_loss: 0.4598 - val_accuracy: 0.8532
# Epoch 43/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.3324 - accuracy: 0.8889 - val_loss: 0.4576 - val_accuracy: 0.8532
# Epoch 44/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.3431 - accuracy: 0.8864 - val_loss: 0.4682 - val_accuracy: 0.8690
# Epoch 45/50
# 63/63 [==============================] - 14s 223ms/step - loss: 0.3226 - accuracy: 0.8884 - val_loss: 0.4608 - val_accuracy: 0.8571
# Epoch 46/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.3061 - accuracy: 0.9097 - val_loss: 0.5025 - val_accuracy: 0.8571
# Epoch 47/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.3060 - accuracy: 0.9023 - val_loss: 0.4371 - val_accuracy: 0.8611
# Epoch 48/50
# 63/63 [==============================] - 14s 224ms/step - loss: 0.3114 - accuracy: 0.9067 - val_loss: 0.4303 - val_accuracy: 0.8889
# Epoch 49/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.2577 - accuracy: 0.9301 - val_loss: 0.4686 - val_accuracy: 0.8452
# Epoch 50/50
# 63/63 [==============================] - 14s 225ms/step - loss: 0.2793 - accuracy: 0.9167 - val_loss: 0.4171 - val_accuracy: 0.8651

# %% [markdown]
# #### 3.2.2 Visualization of Train-Validation Accuracy and Loss

# %%
#Visualization of Train-Validation Accuracy and Loss
accuracy = acnn_wa_hist.history['accuracy']
val_accuracy = acnn_wa_hist.history['val_accuracy']
loss = acnn_wa_hist.history['loss']
val_loss = acnn_wa_hist.history['val_loss']
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# #### 3.2.3 Model Evaluation on Testing Dataset and Summary of Model's structure

# %%
acnn_model_wa.evaluate(X_test,y_test)
# Out:
# 8/8 [==============================] - 1s 73ms/step - loss: 0.3631 - accuracy: 0.8770
# [0.3630885183811188, 0.8769841194152832]

# %%
acnn_model_wa.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 56, 56, 96)        34944
#
#  batch_normalization (BatchN  (None, 56, 56, 96)       384
#  ormalization)
#
#  channel_attention (ChannelA  (None, 56, 56, 96)       0
#  ttention)
#
#  spatial_attention (SpatialA  (None, 56, 56, 96)       0
#  ttention)
#
#  max_pooling2d (MaxPooling2D  (None, 27, 27, 96)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 256)       614656
#
#  batch_normalization_1 (Batc  (None, 27, 27, 256)      1024
#  hNormalization)
#
#  channel_attention_1 (Channe  (None, 27, 27, 256)      0
#  lAttention)
#
#  spatial_attention_1 (Spatia  (None, 27, 27, 256)      0
#  lAttention)
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 256)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 13, 13, 384)       885120
#
#  batch_normalization_2 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  channel_attention_2 (Channe  (None, 13, 13, 384)      0
#  lAttention)
#
#  spatial_attention_2 (Spatia  (None, 13, 13, 384)      0
#  lAttention)
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  batch_normalization_3 (Batc  (None, 13, 13, 384)      1536
#  hNormalization)
#
#  channel_attention_3 (Channe  (None, 13, 13, 384)      0
#  lAttention)
#
#  spatial_attention_3 (Spatia  (None, 13, 13, 384)      0
#  lAttention)
#
#  conv2d_4 (Conv2D)           (None, 13, 13, 256)       884992
#
#  batch_normalization_4 (Batc  (None, 13, 13, 256)      1024
#  hNormalization)
#
#  channel_attention_4 (Channe  (None, 13, 13, 256)      0
#  lAttention)
#
#  spatial_attention_4 (Spatia  (None, 13, 13, 256)      0
#  lAttention)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 9216)              0
#
#  dense (Dense)               (None, 100)               921700
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense_1 (Dense)             (None, 100)               10100
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_2 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 4,684,807
# Trainable params: 4,682,055
# Non-trainable params: 2,752
# _________________________________________________________________

# %%
y_pred = acnn_model_wa.predict(X_test)
wa_pred_classes = [np.argmax(element) for element in y_pred]
# Out:
# 8/8 [==============================] - 1s 94ms/step

# %%
#Confusion Metrics:
classes_shortened = ["BLF", "Brown spot", "Leaf smut"]
conf_matrix = confusion_matrix(y_test, y_pred_classes)
ax = sb.heatmap(conf_matrix, annot=True, cmap='Blues')
ax.set_title('Confusion Matrix\n')
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ')
ax.xaxis.set_ticklabels(classes_shortened)
ax.yaxis.set_ticklabels(classes_shortened)
# Out:
# [Text(0, 0.5, 'BLF'), Text(0, 1.5, 'Brown spot'), Text(0, 2.5, 'Leaf smut')]

# %%
#Classification Report:
print("Classification Report: \n", classification_report(y_test, y_pred_classes, target_names=["Bacterial leaf blight", "Brown spot", "Leaf smut"]))
# Out:
# Classification Report:
#                         precision    recall  f1-score   support
#
# Bacterial leaf blight       0.94      0.78      0.86        87
#            Brown spot       0.89      0.89      0.89        81
#             Leaf smut       0.82      0.96      0.89        84
#
#              accuracy                           0.88       252
#             macro avg       0.88      0.88      0.88       252
#          weighted avg       0.88      0.88      0.88       252

# %%
#Display the error rate:
accuracy = accuracy_score(y_test, y_pred_classes)
print('Error: %.3f' % ((1-accuracy) * 100) + '%')
# Out:
# Error: 12.302%

# %% [markdown]
# # 4. K-Fold Cross Validation

# %% [markdown]
# ### 4.1 Evaluation of Models using K-Fold

# %% [markdown]
# #### 4.1.1 CNN Model with no Visual Attention

# %%
#Change the no. of epochs
seed = 10
np.random.seed(seed)

skf = StratifiedKFold(n_splits=10, random_state= seed, shuffle = True)
cvscores = []
# X_dataset is the feature set and y_dataset is the target
for train_index, test_index in skf.split(X_dataset,y_dataset):
    acnn_model = build_model_no_attention()
    acnn_hist = acnn_model.fit(X_dataset[train_index], y_dataset[train_index], verbose = 1, batch_size = 16,
                               validation_split = 0.1111111111, epochs= 50)
    scores = acnn_model.evaluate(X_dataset[test_index], y_dataset[test_index])
    print("%s: %.2f%%" % (acnn_model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1]*100)
# Out:
# Epoch 1/50
# 126/126 [==============================] - 27s 164ms/step - loss: 1.9166 - accuracy: 0.3894 - val_loss: 1.1399 - val_accuracy: 0.4206
# Epoch 2/50
# 126/126 [==============================] - 17s 138ms/step - loss: 1.2403 - accuracy: 0.4127 - val_loss: 1.0724 - val_accuracy: 0.4921
# Epoch 3/50
# 126/126 [==============================] - 17s 138ms/step - loss: 1.1446 - accuracy: 0.4474 - val_loss: 1.0328 - val_accuracy: 0.4881
# Epoch 4/50
# 126/126 [==============================] - 18s 139ms/step - loss: 1.1050 - accuracy: 0.4474 - val_loss: 1.0329 - val_accuracy: 0.5476
# Epoch 5/50
# 126/126 [==============================] - 17s 137ms/step - loss: 1.0729 - accuracy: 0.4752 - val_loss: 1.0122 - val_accuracy: 0.5317
# Epoch 6/50
# 126/126 [==============================] - 17s 138ms/step - loss: 1.0384 - accuracy: 0.5109 - val_loss: 0.9410 - val_accuracy: 0.6230
# Epoch 7/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.9854 - accuracy: 0.5357 - val_loss: 0.9135 - val_accuracy: 0.6389
# Epoch 8/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.9311 - accuracy: 0.5719 - val_loss: 0.8537 - val_accuracy: 0.6429
# Epoch 9/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.9269 - accuracy: 0.5888 - val_loss: 0.8163 - val_accuracy: 0.7302
# Epoch 10/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.8462 - accuracy: 0.6498 - val_loss: 0.7799 - val_accuracy: 0.7341
# Epoch 11/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.8326 - accuracy: 0.6339 - val_loss: 0.7390 - val_accuracy: 0.7183
# Epoch 12/50
# 126/126 [==============================] - 18s 139ms/step - loss: 0.8120 - accuracy: 0.6503 - val_loss: 0.6972 - val_accuracy: 0.7619
# Epoch 13/50
# 126/126 [==============================] - 18s 140ms/step - loss: 0.7769 - accuracy: 0.6662 - val_loss: 0.7070 - val_accuracy: 0.7619
# Epoch 14/50
# 126/126 [==============================] - 17s 139ms/step - loss: 0.7635 - accuracy: 0.6756 - val_loss: 0.6426 - val_accuracy: 0.7857
# Epoch 15/50
# 126/126 [==============================] - 17s 139ms/step - loss: 0.6927 - accuracy: 0.7192 - val_loss: 0.6359 - val_accuracy: 0.7698
# Epoch 16/50
# 126/126 [==============================] - 18s 141ms/step - loss: 0.6666 - accuracy: 0.7336 - val_loss: 0.5770 - val_accuracy: 0.8333
# Epoch 17/50
# 126/126 [==============================] - 18s 139ms/step - loss: 0.6141 - accuracy: 0.7664 - val_loss: 0.5581 - val_accuracy: 0.8135
# Epoch 18/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.5953 - accuracy: 0.7827 - val_loss: 0.5600 - val_accuracy: 0.8056
# Epoch 19/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.5838 - accuracy: 0.7679 - val_loss: 0.4613 - val_accuracy: 0.8690
# Epoch 20/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.5239 - accuracy: 0.8130 - val_loss: 0.4917 - val_accuracy: 0.8413
# Epoch 21/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.5043 - accuracy: 0.8165 - val_loss: 0.4611 - val_accuracy: 0.8611
# Epoch 22/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.4843 - accuracy: 0.8224 - val_loss: 0.4652 - val_accuracy: 0.8690
# Epoch 23/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.4487 - accuracy: 0.8482 - val_loss: 0.4461 - val_accuracy: 0.8413
# Epoch 24/50
# 126/126 [==============================] - 18s 139ms/step - loss: 0.4717 - accuracy: 0.8393 - val_loss: 0.4053 - val_accuracy: 0.8651
# Epoch 25/50
# 126/126 [==============================] - 18s 139ms/step - loss: 0.4353 - accuracy: 0.8467 - val_loss: 0.4154 - val_accuracy: 0.8770
# Epoch 26/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.4484 - accuracy: 0.8522 - val_loss: 0.3829 - val_accuracy: 0.8849
# Epoch 27/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.3810 - accuracy: 0.8795 - val_loss: 0.3744 - val_accuracy: 0.8849
# Epoch 28/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.3851 - accuracy: 0.8700 - val_loss: 0.3587 - val_accuracy: 0.8968
# Epoch 29/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.3567 - accuracy: 0.8919 - val_loss: 0.3497 - val_accuracy: 0.9167
# Epoch 30/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.3195 - accuracy: 0.8993 - val_loss: 0.3599 - val_accuracy: 0.8770
# Epoch 31/50
# 126/126 [==============================] - 18s 139ms/step - loss: 0.3444 - accuracy: 0.8909 - val_loss: 0.3567 - val_accuracy: 0.8849
# Epoch 32/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.3297 - accuracy: 0.8993 - val_loss: 0.2958 - val_accuracy: 0.9127
# Epoch 33/50
# 126/126 [==============================] - 17s 139ms/step - loss: 0.3091 - accuracy: 0.9028 - val_loss: 0.3224 - val_accuracy: 0.9167
# Epoch 34/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.3152 - accuracy: 0.8958 - val_loss: 0.2860 - val_accuracy: 0.9325
# Epoch 35/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.2969 - accuracy: 0.9152 - val_loss: 0.3073 - val_accuracy: 0.9087
# Epoch 36/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.2614 - accuracy: 0.9221 - val_loss: 0.2854 - val_accuracy: 0.9087
# Epoch 37/50
# 126/126 [==============================] - 17s 139ms/step - loss: 0.2648 - accuracy: 0.9256 - val_loss: 0.2858 - val_accuracy: 0.9008
# Epoch 38/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.2269 - accuracy: 0.9350 - val_loss: 0.2877 - val_accuracy: 0.9325
# Epoch 39/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.2351 - accuracy: 0.9340 - val_loss: 0.2815 - val_accuracy: 0.9286
# Epoch 40/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.2253 - accuracy: 0.9385 - val_loss: 0.3222 - val_accuracy: 0.8968
# Epoch 41/50
# 126/126 [==============================] - 17s 138ms/step - loss: 0.2173 - accuracy: 0.9430 - val_loss: 0.2514 - val_accuracy: 0.9286
# Epoch 42/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.2332 - accuracy: 0.9360 - val_loss: 0.3410 - val_accuracy: 0.8968
# Epoch 43/50
# 126/126 [==============================] - 17s 137ms/step - loss: 0.2145 - accuracy: 0.9464 - val_loss: 0.2625 - val_accuracy: 0.9286
# Epoch 44/50
# 126/126 [==============================] - 17s 139ms/step - loss: 0.2057 - accuracy: 0.9425 - val_loss: 0.2312 - val_accuracy: 0.9444
# Epoch 45/50
# 126/126 [==============================] - 18s 140ms/step - loss: 0.2156 - accuracy: 0.9410 - val_loss: 0.3164 - val_accuracy: 0.9167
# Epoch 46/50
# 126/126 [==============================] - 17s 139ms/step - loss: 0.1965 - accuracy: 0.9489 - val_loss: 0.2639 - val_accuracy: 0.9325
# Epoch 47/50
#  99/126 [======================>.......] - ETA: 3s - loss: 0.1860 - accuracy: 0.9583

# %% [markdown]
# #### 4.1.1.1 Overall Performance of CNN model without Visual Attention

# %%
print("%.2f%% (+/-%.2f%%)" % (np.mean(cvscores), np.std(cvscores)))

# %% [markdown]
# #### 4.1.2 CNN Model with Visual Attention

# %%
#Change the no. of epochs
seed = 10
np.random.seed(seed)

skf = StratifiedKFold(n_splits=10, random_state= seed, shuffle = True)
cvscores = []
# X_dataset is the feature set and y_dataset is the target
for train_index, test_index in skf.split(X_dataset,y_dataset):
    acnn_model_wa = build_model_with_attention()
    acnn_wa_hist = acnn_model_wa.fit(X_dataset[train_index], y_dataset[train_index], 
                                     verbose = 1, batch_size = 16,validation_split = 0.1111111111, epochs=50)
    scores = acnn_model_wa.evaluate(X_dataset[test_index], y_dataset[test_index])
    print("%s: %.2f%%" % (acnn_model_wa.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1]*100)

# %% [markdown]
# #### 4.1.2.1 Overall Performance of CNN model with Visual Attention

# %%
print("%.2f%% (+/-%.2f%%)" % (np.mean(cvscores), np.std(cvscores)))

# %% [markdown]
# ### 4.2 Visualization from split of K-Fold

# %%
#Visualize images in training dataset
fig, axes = plt.subplots(2, 5, figsize = (15,10))
#TRUE LABEL of Training Data
for index in range(10):   
    ax = axes[index//5, index%5]
    ax.imshow(X_train[index])
    ax.set_title(classes[y_train[index]]) 
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5. Comparison of CNN model w/ and w/o Attention

# %% [markdown]
# ### 5.1 Loading and Predicting Testing dataset using the 2 Models

# %%
saved_model = tf.keras.models.load_model('model_checkpoints/acnn_model_no_attention_50_v1.1.h5')

# %%
saved_model.evaluate(X_test, y_test)

# %%
no_attention_pred = saved_model.predict(X_test)

with_attention_pred = acnn_model_wa.predict(X_test)
print(no_attention_pred[:5])
print(with_attention_pred[:5])

# %%
#PREDICTED LABEL
na_pred_labels = np.argmax(no_attention_pred, axis = 1)
wa_pred_labels = np.argmax(with_attention_pred, axis = 1)
print("Actual Labels")
print(y_test[:5])
print("===================")
print("No Attention Predicted Labels")
print(na_pred_labels[1:])
print("===================")
print("With Attention Predicted Labels")
print(wa_pred_labels[1:])

# %% [markdown]
# ### 5.2 Visualization of TRUE and PREDICTED Labels

# %%
fig, axes = plt.subplots(2, 5, figsize = (15,10))
#TRUE LABEL of Testing DATASET
for index in range(10):   
#     plt.figure(figsize = (15,2))
    ax = axes[index//5, index%5]
    ax.imshow(X_test[index])
    ax.set_title(classes[na_test[index]]) 
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 5, figsize = (15,10))
#PREDICTED LABEL of ACNN model with no attention
for index in range(10):   
#     plt.figure(figsize = (15,2))
    ax = axes[index//5, index%5]
    ax.imshow(X_test[index])
    ax.set_title(classes[wa_pred_classes[index]]) 
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(3, 5, figsize = (15,10))
#PREDICTED LABEL of ACNN model with attention
for index in range(15):   
#     plt.figure(figsize = (15,2))
    ax = axes[index//5, index%5]
    ax.imshow(X_test[index])
    ax.set_title(classes[y_pred_classes[index]]) 
plt.tight_layout()
plt.show()
